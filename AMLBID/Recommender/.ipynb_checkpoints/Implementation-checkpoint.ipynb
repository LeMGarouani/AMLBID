# %% [markdown]
# # Extract Metafeatures

# %%
from MetafeatureExtraction.metafeatures import *

path_to_datasets = 'Datasets/new/'
ExtractMetaFeatures(path_to_datasets)
# Out:
# Dataset 1(Datasets/new\2dplanes.csv)
# Dataset 2(Datasets/new\abalone.csv)
# Dataset 3(Datasets/new\adult.csv)
# Dataset 4(Datasets/new\agaricus_lepiota.csv)
# Dataset 5(Datasets/new\allbp.csv)
# Dataset 6(Datasets/new\allhyper.csv)
# Dataset 7(Datasets/new\analcatdata_authorship.csv)
# Dataset 8(Datasets/new\analcatdata_supreme.csv)
# Dataset 9(Datasets/new\ann_thyroid.csv)
# Dataset 10(Datasets/new\bank32nh.csv)
# Dataset 11(Datasets/new\bank8FM.csv)
# Dataset 12(Datasets/new\BNG_breast-w.csv)
# Dataset 13(Datasets/new\car-evaluation.csv)
# Dataset 14(Datasets/new\chess.csv)
# Dataset 15(Datasets/new\churn.csv)
# Dataset 16(Datasets/new\clean2.csv)
# Dataset 17(Datasets/new\coil2000.csv)
# Dataset 18(Datasets/new\connect_4.csv)
# Dataset 19(Datasets/new\cpu_act.csv)
# Dataset 20(Datasets/new\cpu_small.csv)
# Dataset 21(Datasets/new\dataset7_3.csv)
# Dataset 22(Datasets/new\dataset_30_page-blocks.csv)
# Dataset 23(Datasets/new\dataset_36_segment.csv)
# Dataset 24(Datasets/new\default of credit card clients.csv)
# Dataset 25(Datasets/new\delta_ailerons.csv)
# Dataset 26(Datasets/new\delta_elevators.csv)
# Dataset 27(Datasets/new\dis.csv)
# Dataset 28(Datasets/new\dna.csv)
# Dataset 29(Datasets/new\eeg-eye-state.csv)
# Dataset 30(Datasets/new\Electrical Grid Stability Simulated Data.csv)
# Dataset 31(Datasets/new\electricity-normalized.csv)
# Dataset 32(Datasets/new\elevators.csv)
# Dataset 33(Datasets/new\eye_movements.csv)
# Dataset 34(Datasets/new\fars.csv)
# Dataset 35(Datasets/new\file7a97574fa9ae.csv)
# Dataset 36(Datasets/new\FOREX_audcad-day-High.csv)
# Dataset 37(Datasets/new\FOREX_audchf-day-High.csv)
# Dataset 38(Datasets/new\FOREX_audchf-hour-High.csv)
# Dataset 39(Datasets/new\FOREX_audjpy-day-High.csv)
# Dataset 40(Datasets/new\FOREX_audnzd-day-High.csv)
# Dataset 41(Datasets/new\FOREX_audnzd-hour-High.csv)
# Dataset 42(Datasets/new\FOREX_audsgd-day-High.csv)
# Dataset 43(Datasets/new\FOREX_audsgd-hour-High.csv)
# Dataset 44(Datasets/new\FOREX_audusd-day-High.csv)
# Dataset 45(Datasets/new\FOREX_audusd-hour-High.csv)
# Dataset 46(Datasets/new\FOREX_cadchf-day-High.csv)
# Dataset 47(Datasets/new\FOREX_cadchf-hour-High.csv)
# Dataset 48(Datasets/new\FOREX_cadjpy-day-High.csv)
# Dataset 49(Datasets/new\FOREX_cadjpy-hour-High.csv)
# Dataset 50(Datasets/new\FOREX_chfjpy-day-High.csv)
# Dataset 51(Datasets/new\FOREX_chfjpy-hour-High.csv)
# Dataset 52(Datasets/new\FOREX_chfsgd-day-High.csv)
# Dataset 53(Datasets/new\FOREX_chfsgd-hour-High.csv)
# Dataset 54(Datasets/new\FOREX_euraud-day-High.csv)
# Dataset 55(Datasets/new\FOREX_euraud-hour-High.csv)
# Dataset 56(Datasets/new\FOREX_eurcad-day-High.csv)
# Dataset 57(Datasets/new\FOREX_eurcad-hour-High.csv)
# Dataset 58(Datasets/new\FOREX_eurchf-day-High.csv)
# Dataset 59(Datasets/new\FOREX_eurchf-hour-High.csv)
# Dataset 60(Datasets/new\FOREX_eurdkk-day-High.csv)
# Dataset 61(Datasets/new\FOREX_eurdkk-hour-High.csv)
# Dataset 62(Datasets/new\FOREX_eurgbp-day-High.csv)
# Dataset 63(Datasets/new\FOREX_eurhkd-day-High.csv)
# Dataset 64(Datasets/new\FOREX_eurhkd-hour-High.csv)
# Dataset 65(Datasets/new\FOREX_eurhuf-day-High.csv)
# Dataset 66(Datasets/new\FOREX_eurhuf-hour-High.csv)
# Dataset 67(Datasets/new\FOREX_eurjpy-day-High.csv)
# Dataset 68(Datasets/new\FOREX_eurjpy-hour-High.csv)
# Dataset 69(Datasets/new\FOREX_eurnok-day-High.csv)
# Dataset 70(Datasets/new\FOREX_eurnok-hour-High.csv)
# Dataset 71(Datasets/new\FOREX_eurnzd-day-High.csv)
# Dataset 72(Datasets/new\FOREX_eurpln-day-High.csv)
# Dataset 73(Datasets/new\FOREX_eurpln-hour-High.csv)
# Dataset 74(Datasets/new\FOREX_eurrub-day-High.csv)
# Dataset 75(Datasets/new\FOREX_eurrub-hour-High.csv)
# Dataset 76(Datasets/new\FOREX_eursek-day-High.csv)
# Dataset 77(Datasets/new\FOREX_eursek-hour-High.csv)
# Dataset 78(Datasets/new\FOREX_eursgd-day-High.csv)
# Dataset 79(Datasets/new\FOREX_eursgd-hour-High.csv)
# Dataset 80(Datasets/new\FOREX_eurtry-day-High.csv)
# Dataset 81(Datasets/new\FOREX_eurusd-day-High.csv)
# Dataset 82(Datasets/new\FOREX_eurusd-hour-High.csv)
# Dataset 83(Datasets/new\FOREX_gbpusd-day-High.csv)
# Dataset 84(Datasets/new\FOREX_gbpusd-hour-High.csv)
# Dataset 85(Datasets/new\FOREX_nzdusd-day-High.csv)
# Dataset 86(Datasets/new\FOREX_usdcad-day-High.csv)
# Dataset 87(Datasets/new\FOREX_usdcad-hour-High.csv)
# Dataset 88(Datasets/new\FOREX_usdchf-day-High.csv)
# Dataset 89(Datasets/new\FOREX_usdchf-hour-High.csv)
# Dataset 90(Datasets/new\FOREX_usddkk-day-High.csv)
# Dataset 91(Datasets/new\FOREX_usdjpy-day-High.csv)
# Dataset 92(Datasets/new\FOREX_usdjpy-hour-High.csv)
# Dataset 93(Datasets/new\fried.csv)
# Dataset 94(Datasets/new\fri_c0_1000_10.csv)
# Dataset 95(Datasets/new\fri_c0_1000_25.csv)
# Dataset 96(Datasets/new\fri_c0_1000_5.csv)
# Dataset 97(Datasets/new\fri_c1_1000_10.csv)
# Dataset 98(Datasets/new\fri_c1_1000_25.csv)
# Dataset 99(Datasets/new\fri_c1_1000_5.csv)
# Dataset 100(Datasets/new\fri_c2_1000_10.csv)
# Dataset 101(Datasets/new\fri_c2_1000_25.csv)
# Dataset 102(Datasets/new\fri_c2_1000_5.csv)
# Dataset 103(Datasets/new\fri_c3_1000_10.csv)
# Dataset 104(Datasets/new\fri_c3_1000_25.csv)
# Dataset 105(Datasets/new\fri_c3_1000_5.csv)
# Dataset 106(Datasets/new\fri_c4_1000_10.csv)
# Dataset 107(Datasets/new\fri_c4_1000_25.csv)
# Dataset 108(Datasets/new\full_data_carla.csv)
# Dataset 109(Datasets/new\GAMETES_Epistasis_2-Way_20atts_0.1H_EDM-1_1.csv)
# Dataset 110(Datasets/new\GAMETES_Epistasis_2_Way_1000atts_0.4H_EDM_1_EDM_1_1.csv)
# Dataset 111(Datasets/new\GAMETES_Heterogeneity_20atts_1600_Het_0.4_0.2_75_EDM-2_001.csv)
# Dataset 112(Datasets/new\higgs.csv)
# Dataset 113(Datasets/new\Hill_Valley_without_noise.csv)
# Dataset 114(Datasets/new\Hill_Valley_with_noise.csv)
# Dataset 115(Datasets/new\houses.csv)
# Dataset 116(Datasets/new\house_16H.csv)
# Dataset 117(Datasets/new\house_8L.csv)
# Dataset 118(Datasets/new\HTRU.csv)
# Dataset 119(Datasets/new\hypothyroid.csv)
# Dataset 120(Datasets/new\ionosphere.csv)
# Dataset 121(Datasets/new\jungle_chess_2pcs_raw_endgame_complete.csv)
# Dataset 122(Datasets/new\kc1.csv)
# Dataset 123(Datasets/new\kdd_JapaneseVowels.csv)
# Dataset 124(Datasets/new\kin8nm.csv)
# Dataset 125(Datasets/new\krkopt.csv)
# Dataset 126(Datasets/new\kr_vs_kp.csv)
# Dataset 127(Datasets/new\led24.csv)
# Dataset 128(Datasets/new\letter-challenge-unlabeled.csv)
# Dataset 129(Datasets/new\letter.csv)
# Dataset 130(Datasets/new\magic.csv)
# Dataset 131(Datasets/new\magic04.csv)
# Dataset 132(Datasets/new\mc1.csv)
# Dataset 133(Datasets/new\mfeat-morphological.csv)
# Dataset 134(Datasets/new\mfeat_factors.csv)
# Dataset 135(Datasets/new\mfeat_fourier.csv)
# Dataset 136(Datasets/new\mfeat_karhunen.csv)
# Dataset 137(Datasets/new\mfeat_pixel.csv)
# Dataset 138(Datasets/new\mfeat_zernike.csv)
# Dataset 139(Datasets/new\movement_libras.csv)
# Dataset 140(Datasets/new\mozilla4.csv)
# Dataset 141(Datasets/new\mushroom.csv)
# Dataset 142(Datasets/new\mv.csv)
# Dataset 143(Datasets/new\nursery.csv)
# Dataset 144(Datasets/new\optdigits.csv)
# Dataset 145(Datasets/new\page-blocks.csv)
# Dataset 146(Datasets/new\pc2.csv)
# Dataset 147(Datasets/new\php2PPvrr.csv)
# Dataset 148(Datasets/new\php3YXJ45.csv)
# Dataset 149(Datasets/new\php5s7Ep8.csv)
# Dataset 150(Datasets/new\php8Mz7BG.csv)
# Dataset 151(Datasets/new\php9xWOpn.csv)
# Dataset 152(Datasets/new\phpcSeK3V.csv)
# Dataset 153(Datasets/new\phpfGCaQC.csv)
# Dataset 154(Datasets/new\phpfrJpBS.csv)
# Dataset 155(Datasets/new\phpfUae7X.csv)
# Dataset 156(Datasets/new\phplE7q6h.csv)
# Dataset 157(Datasets/new\phpMD2hR6.csv)
# Dataset 158(Datasets/new\phpmPOD5A.csv)
# Dataset 159(Datasets/new\phpn1jVwe.csv)
# Dataset 160(Datasets/new\phpNevWWL.csv)
# Dataset 161(Datasets/new\phpNzIybr.csv)
# Dataset 162(Datasets/new\phposACMs.csv)
# Dataset 163(Datasets/new\phpqJqmHb.csv)
# Dataset 164(Datasets/new\phpRP7su7.csv)
# Dataset 165(Datasets/new\phpt5wsw7.csv)
# Dataset 166(Datasets/new\phpTJRsqa.csv)
# Dataset 167(Datasets/new\phptrBBuY.csv)
# Dataset 168(Datasets/new\phpV5QYya.csv)
# Dataset 169(Datasets/new\phpVeNa5j.csv)
# Dataset 170(Datasets/new\phpW0AXSQ.csv)
# Dataset 171(Datasets/new\phpWfYmlu.csv)
# Dataset 172(Datasets/new\phpxijhaP.csv)
# Dataset 173(Datasets/new\phpyM5ND4.csv)
# Dataset 174(Datasets/new\phpZrCzJR.csv)
# Dataset 175(Datasets/new\pollen.csv)
# Dataset 176(Datasets/new\puma32H.csv)
# Dataset 177(Datasets/new\puma8NH.csv)
# Dataset 178(Datasets/new\ring.csv)
# Dataset 179(Datasets/new\sat.csv)
# Dataset 180(Datasets/new\Satellite.csv)
# Dataset 181(Datasets/new\segment.csv)
# Dataset 182(Datasets/new\segmentation.csv)
# Dataset 183(Datasets/new\sensor_readings_24.csv)
# Dataset 184(Datasets/new\shuttle.csv)
# Dataset 185(Datasets/new\sick_numeric2.csv)
# Dataset 186(Datasets/new\sleep.csv)
# Dataset 187(Datasets/new\space_ga.csv)
# Dataset 188(Datasets/new\spambase.csv)
# Dataset 189(Datasets/new\splice.csv)
# Dataset 190(Datasets/new\steel-plates-fault.csv)
# Dataset 191(Datasets/new\texture.csv)
# Dataset 192(Datasets/new\tokyo1.csv)
# Dataset 193(Datasets/new\vehicle.csv)
# Dataset 194(Datasets/new\visualizing_soil.csv)
# Dataset 195(Datasets/new\vowel.csv)
# Dataset 196(Datasets/new\waveform.csv)
# Dataset 197(Datasets/new\waveform_21.csv)
# Dataset 198(Datasets/new\waveform_40.csv)
# Dataset 199(Datasets/new\wind.csv)
# Dataset 200(Datasets/new\wine-quality-red.csv)
#     nr_classes  nr_instances  log_nr_instances  nr_features  log_nr_features  \
# 0            2         40768         10.615653            6         1.791759
# 0            2          4177          8.337349            3         1.098612
# 0            2         48842         10.796346           10         2.302585
# 0            2          8145          9.005160           17         2.833213
# 0            3          3772          8.235361           23         3.135494
# ..         ...           ...               ...          ...              ...
# 0            3          4999          8.516993           21         3.044522
# 0            3          5000          8.517193           21         3.044522
# 0            3          5000          8.517193           40         3.688879
# 0            2          6574          8.790878           11         2.397895
# 0            6          1599          7.377134           11         2.397895
#
#     dataset_ratio  skew_min   skew_std  skew_mean   skew_q1  ...   mi_mean  \
# 0        0.000147  0.000406   0.003415   0.004237  0.002705  ...  0.002970
# 0        0.000718  0.591852   0.014537   0.606389  0.599121  ...  0.171830
# 0        0.000205  0.016328   3.444393   2.569718  0.358015  ...  0.044234
# 0        0.002087  0.060920   1.892576   1.670088  0.550920  ...  0.134635
# 0        0.006098  0.066356  12.161330   6.772093  1.530039  ...  0.010953
# ..            ...       ...        ...        ...       ...  ...       ...
# 0        0.004201  0.002480   0.096823   0.141208  0.035160  ...  0.165529
# 0        0.004200  0.002787   0.096899   0.141052  0.035229  ...  0.165467
# 0        0.008000  0.003449   0.088484   0.085805  0.022696  ...  0.084651
# 0        0.001673  0.498126   0.124728   0.617839  0.530242  ...  0.198848
# 0        0.006879  0.071288   1.793593   1.613573  0.268069  ...  0.062778
#
#       mi_std    mi_max  equiv_nr_feat  noise_signal_ratio  Landmarker_1NN  \
# 0   0.004671  0.012089     336.684437           33.843195        0.512780
# 0   0.018860  0.190690       5.819660            0.186164        0.686134
# 0   0.038847  0.114663      17.946263            0.937219        0.811822
# 0   0.091262  0.333500       7.419689           -0.192794        0.993862
# 0   0.020991  0.079326      25.116494            5.595307        0.953870
# ..       ...       ...            ...                 ...             ...
# 0   0.076642  0.255610       9.574469            0.317522        0.784955
# 0   0.076572  0.255674       9.578043            0.316764        0.780000
# 0   0.098268  0.265126      18.722509            1.542386        0.770000
# 0   0.057918  0.280831       5.013586            0.022005        0.784144
# 0   0.044203  0.172255      27.224001            2.179431        0.593483
#
#     Landmarker_dt  Landmarker_gnb  Landmarker_lda               dataset
# 0        0.574617        0.576702        0.576138          2dplanes.csv
# 0        0.683018        0.741443        0.757714           abalone.csv
# 0        0.840690        0.795995        0.785226             adult.csv
# 0        0.993984        0.787598        0.942908  agaricus_lepiota.csv
# 0        0.967922        0.273054        0.963416             allbp.csv
# ..            ...             ...             ...                   ...
# 0        0.754750        0.809366        0.859177          waveform.csv
# 0        0.755800        0.808800        0.862800       waveform_21.csv
# 0        0.749600        0.800600        0.860800       waveform_40.csv
# 0        0.785820        0.809400        0.844081              wind.csv
# 0        0.631671        0.559709        0.594760  wine-quality-red.csv
#
# [200 rows x 42 columns]

# %% [markdown]
# To start collecting data for a given classifier over all datasets

# %% [raw]
# +AdaBoost': params_adaboost,
# +RandomForest': params_random_forest,
# +SVM': params_svm,
# +ExtraTrees': params_random_forest,
# +GradientBoosting': params_gboosting,
# +DecisionTree': params_decision_tree,
# +LogisticRegression': param_lr,
# +PassiveAggressiveClassifier':param_pass_agg, //a chaaaaaanger
# +SGDClassifier' : param_sgd,
# +LinearSVC' : LinearSVC  // a chaaaanger aussi

# %% [markdown]
# # classification/algorithm

# %%
from ModelsCode.classification import *
from pandas import DataFrame
path_to_datasets = 'Datasets/10/'
classification_per_algorithm(path=path_to_datasets, algorithm='SVM')
# Out:
# Dataset 1(Datasets/10\2dplanes.csv) out of 1
#
# 1/500
# CV 5/5
#
# 2/500
# CV 4/5The following error occurred in case of the dataset Datasets/10\2dplanes.csv:
# name 'sys' is not defined
# Performance data is collected!
#  Total time: 0.5880645887777778 hours

# %%
from DataCollection.functions import *

path_to_datasets = 'Datasets/DS/'
classification_per_algorithm(path=path_to_datasets, algorithm='DecisionTree')

# %% [markdown]
# Conduct fANOVA on the data

# %%
from fANOVA.fanova_functions import *
do_fanova(dataset_name='PerformanceData/AB_results_total.csv', algorithm='AdaBoost')

# %% [markdown]
# Create the Database object to import the collected data in desired formats

# %%
from Tools.database import Database
db = Database()
per_dataset_acc = db.get_per_dataset_accuracies()
per_dataset_acc.head()
